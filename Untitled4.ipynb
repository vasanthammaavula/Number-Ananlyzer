# %% [markdown]
# <a href="https://colab.research.google.com/github/vasanthammaavula/Number-Ananlyzer/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/customer_churn_demo_v2(1).csv

# %%
df
# Out:
#      customer_id  age gender   location plan_type  hours_per_week  \
# 0           1001   45      F  Bengaluru     Basic             3.5
# 1           1002   32      M  Bengaluru   Premium             6.5
# 2           1003   50      F     Mumbai     Basic             2.5
# 3           1004   49      F       Pune   Premium             6.9
# 4           1005   36      M      Delhi   Premium             6.2
# ..           ...  ...    ...        ...       ...             ...
# 115         1116   36      F      Delhi   Premium             7.2
# 116         1117   45      F      Delhi     Basic             3.0
# 117         1118   35      F       Pune     Basic             2.0
# 118         1119   44      F  Bengaluru   Premium             4.8
# 119         1120   18      F      Delhi     Basic             3.2
#
#      last_login_days_ago  satisfaction_score      cancellation_reason churned
# 0                      3                   4                      NaN      No
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customer_id          120 non-null    int64
#  1   age                  120 non-null    int64
#  2   gender               120 non-null    object
#  3   location             120 non-null    object
#  4   plan_type            120 non-null    object
#  5   hours_per_week       120 non-null    float64
#  6   last_login_days_ago  120 non-null    int64
#  7   satisfaction_score   120 non-null    int64
#  8   cancellation_reason  29 non-null     object
#  9   churned              120 non-null    object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 9.5+ KB

# %%
print(df.groupby("plan_type")["churned"].value_counts(normalize=True).mul(100).round(1))
# Out:
# plan_type  churned
# Basic      No         59.2
#            Yes        40.8
# Premium    No         87.3
#            Yes        12.7
# Name: proportion, dtype: float64

# %%
df.groupby("churned")["hours_per_week"].mean()
# Out:
# churned
# No     5.761538
# Yes    3.979310
# Name: hours_per_week, dtype: float64

# %%
df.groupby("churned")["satisfaction_score"].mean()
# Out:
# churned
# No     3.527473
# Yes    3.379310
# Name: satisfaction_score, dtype: float64

# %%
df.loc[df["churned"]=="yes", "cancellation_reason"].value_counts().plot(kind="bar")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-3470437566.py in <cell line: 0>()
# ----> 1 df.loc[df["churned"]=="yes", "cancellation_reason"].value_counts().plot(kind="bar")
#
# /usr/local/lib/python3.12/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#    1028                     data.columns = label_name
#    1029
# -> 1030         return plot_backend.plot(data, kind=kind, **kwargs)
#    1031
#    1032     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.12/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ...

# %%
df.loc[df["churned"]=="Yes", "cancellation_reason"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='cancellation_reason'>

# %%
plt.rcParams['figure.figsize'] = (6,4)
